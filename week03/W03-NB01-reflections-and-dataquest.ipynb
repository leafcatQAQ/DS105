# %% [markdown]
# # 📝 Week 03 Practice – File Systems and Python Control Flow
#
# **LSE DS105W – Data for Data Science (2025/26)**
#
# - 📅 Date: [Add today's date]
# - 👤 Name: [Add your name]
# - 🎯 Purpose: Learn Terminal navigation and Python loops/conditionals
